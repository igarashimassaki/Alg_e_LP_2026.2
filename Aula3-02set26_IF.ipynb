# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/Alg_e_LP_2026.2/blob/main/Aula3-02set26_IF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exemplo Programa verifica PAR ou IMPAR

# %% [markdown]
# # RESOLUÇÃO 1

# %%
num = int(input('Digite um número inteiro: '))
resto = num%2
if num%2==0:
  print('PAR')
else:
  print("ÍMPAR")
# Out:
# Digite um número inteiro: 5
# ÍMPAR

# %% [markdown]
# # RESOLUÇÃO 2

# %%
num = int(input('Digite um número inteiro: '))
if num%2==0:
  print('PAR')
if num%2==1:
  print("ÍMPAR")
# Out:
# Digite um número inteiro: 8
# PAR

# %% [markdown]
# # RESOLUÇÃO 3

# %%
num = int(input('Digite um número inteiro: '))
if num%2!=0:
  print("ÍMPAR")
else:
  print('PAR')
# Out:
# Digite um número inteiro: 7
# ÍMPAR
