# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/Alg_e_LP_2026.2/blob/main/Alg_%26_LP_2026_2_Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notas de Aula**
# ## Explicação do prof. Ex01

# %%
# Código exemplo calc media dois valores
valor1 = float(input("Digite o primeiro valor: "))
valor2 = float(input("Digite o segundo valor: "))
soma = (valor1 + valor2)
print(soma)
# Out:
# Digite o primeiro valor: 4
# Digite o segundo valor: 5
# 9.0

# %%
type(valor1)
# Out:
# float
