# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/Alg_e_LP_2026.2/blob/main/Estruturas_Condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dicas do professor**
# Estruturas condicionais

# %%
num = int(input("Enter a number: "))
resto = num%2
if resto==0:
  print("É PAR")
else:
  print("É IMPAR")
# Out:
# Enter a number: 56
# É PAR
