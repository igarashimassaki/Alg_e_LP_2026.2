# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/Alg_e_LP_2026.2/blob/main/03_Estrutura_Condicional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resolução 1

# %%
num = int(input("Digite valor inteiro:"))
resto = num%2
print(resto)
if resto==0:
  print("É PAR")
else:
  print("É ÍMPAR")
# Out:
# Digite valor inteiro:4
# 0
# É PAR

# %% [markdown]
# # Resolução 2

# %%
num = int(input("Digite valor inteiro:"))
resto = num%2
print(resto)
if resto==0:
  print("É PAR")
if resto==1:
  print("É ÍMPAR")

# %% [markdown]
# # Resolução 3

# %%
num = int(input("Digite valor inteiro:"))
resto = num%2
print(resto)
if resto!=0:
  print("É ÍMPAR")
else:
  print("É PAR")
