# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/Alg_e_LP_2026.2/blob/main/C%C3%B3pia_de_Untitled89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notas de aula do Massaki**
# ## SUBTÍTULO 1
# ### SUBTPITULO 2
#
#
# # ANOTE AQUI O QUE O MALA DO MASSAKI FALOU

# %%
num = int(input("Digite número"))
# ANOTAÇÃO
if num%2==0:
  print("É PAR")
else:
  print("É ÍMPAR")
# Out:
# Digite número7
# É ÍMPAR

# %%
print(2*resto)
# Out:
# 2
